# %%
import torch
import numpy as np
import pandas as pd
import torch.nn.functional as F
from torch_explain.nn.concepts import ConceptReasoningLayer
from torch_explain import datasets
import torch_explain as te
from enr_utils import get_dataset
from enr_utils import load_DCRBase, create_df_DCRBase
from enr_utils import plot_feature_importance_per_class, plot_permutation_importance_per_class
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %%
def eval_DCRBase(dataset_name):
    #Concept Importance
    plot_feature_importance_per_class(dataset_name)

    #Permutation Importance
    plot_permutation_importance_per_class(dataset_name)

# %% [markdown]
# XOR

# %%
dataset_name = 'XOR'
eval_DCRBase(dataset_name)

# %% [markdown]
# Trigonometry

# %%
dataset_name = 'trigonometry'
eval_DCRBase(dataset_name)

# %% [markdown]
# Dot

# %%
dataset_name = 'dot'
eval_DCRBase(dataset_name)

# %% [markdown]
# Is Bin Even

# %%
dataset_name = 'IsBinEven'
eval_DCRBase(dataset_name)

# %% [markdown]
# Mux41

# %%
dataset_name = 'mux41'
eval_DCRBase(dataset_name)

# %% [markdown]
# Mux41 two inputs

# %%
dataset_name = 'Mux41_twoInputs'
eval_DCRBase(dataset_name)

# %% [markdown]
# two Muxes

# %%
dataset_name = 'two_Muxes'
eval_DCRBase(dataset_name)
